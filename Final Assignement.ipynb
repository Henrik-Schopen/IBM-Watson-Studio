# %% [markdown]
# <h1 style="text-align:center;">Coursera Final Assignement</h1>

# %% [markdown]
# In this notebook i will present to you the final assignemet for the coursera cours week 4

# %% [markdown]
# Here is a list of the most popular Data science languages:
# <ul>
#     <li>python</li>
#     <li>R</li>
#     <li>SQL</li>
# </ul>

# %% [markdown]
# Here is a list of the most popular Data science libraries:
# <ul>
#     <li>NumPy</li>
#     <li>Pandas</li>
#     <li>Matplotlib</li>
#     <li>TensorFlow</li>
# </ul>

# %% [markdown]
# Here is a list of the most popular Data science tools:
# <ul>
#     <li>ApacheSpark</li>
#     <li>Apache Hadoop</li>
#     <li>MATLAB</li>
#     <li>Tableau</li>
# </ul>

# %% [markdown]
# Arithmetic expressions examples:
# <ul>
#     <li>3 + 4</li>
#     <li>5 * 2</li>
#     <li>10 / 2</li>
#     <li>7 - 2</li>
#     <li>2 * (4 + 1)</li>
#     <li>w10 - 2 * 3</li>
#     <li>(8 + 4) / 2</li>
#     <li>12 % 5 (modulus operator, gives remainder after division)</li>
#     <li>2 ** 3 (exponentiation operator, gives 2 raised to the power of 3)</li>
# <ul>

# %%
a = 10
b = 5
c = 15
print(a*b)
print(c/3)
print(b**c)
print(a+b+c)
# Out:
# 50
# 5.0
# 30517578125
# 30

# %%
def minutes_to_hours(minutes):
    hours = minutes / 60
    print("There are", hours, "hours in", minutes, "minutes.")
    
minutes_to_hours(60)
# Out:
# There are 1.0 hours in 60 minutes.

# %% [markdown]
# The Objectiv of this notebook is:
# - to improve my understanding of Jupyter Notebook
# - to advance my programming skills
# - get to understand the usage of Jupyter Notebook
# - share my knowledge with others
# - get alot of points (:

# %% [markdown]
# <em>Henrik Schopen</em>
